# %%
from sportsdataverse import wbb
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import date

#w = wbb.espn_wbb_pbp(401414529)
s = wbb.load_wbb_schedule(2022)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]c:\Users\cfinl\AppData\Local\Programs\Python\Python39\lib\site-packages\sportsdataverse\wbb\wbb_loaders.py:119: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(i_data)
# 100%|██████████| 1/1 [00:01<00:00,  1.81s/it]

# %%
q=wbb.load_wbb_pbp(2022)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]c:\Users\cfinl\AppData\Local\Programs\Python\Python39\lib\site-packages\sportsdataverse\wbb\wbb_loaders.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(i_data)
# 100%|██████████| 1/1 [00:30<00:00, 30.43s/it]

# %%
s['date'] = pd.to_datetime(s['date'])
s['date'] = s['date'].dt.tz_convert('US/Eastern')
s.loc[s['date'].dt.date == date(2022,1,25),['home_short_display_name','away_short_display_name']]
#s.columns
# Out:
#      home_short_display_name away_short_display_name
# 2410              Pepperdine                     LMU
# 2411                    UCSB          CSU Northridge
# 2412                  Auburn                Kentucky
# 2413              Georgetown              St. John's
# 2414           Saint Peter's               Manhattan
# 2415           Wichita State           East Carolina
# 2416              High Point                Longwood
# 2417           West Virginia                     TCU
# 2418           UNC Asheville                  NC A&T
# 2419                Virginia              Notre Dame
# 2420              Penn State                    Iowa
# 2421              SC Upstate            Gardner-Webb
# 2422           Charleston So                 Radford
# 2423           Chicago State           New Mexico St

# %%
s['date'].dt.date == date(2022,4,3)
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6003    False
# 6004    False
# 6005    False
# 6006    False
# 6007    False
# Name: date, Length: 6008, dtype: bool

# %%
r = requests.get('https://www.ncaa.com/scoreboard/basketball-women/d1/2022/01/05')
soup = BeautifulSoup(r.text,'html.parser')

for g in soup.find_all('a',class_='gamePod-link'):
    #print(g['href'].split('/')[-1])
    for h in g.find_all('span',class_='gamePod-game-team-name'):
        print(h.text,end=' ')
    print()
# Out:
# Richmond George Washington
# UNCW Northeastern
# North Florida FGCU
# Vermont New Hampshire
# Duquesne VCU
# Army West Point Lehigh
# Navy Bucknell
# Colgate American
# Texas Southern Grambling
# Alabama A&M Mississippi Val.
# Prairie View Southern U.
# Alcorn Jackson St.
# Alabama St. Ark.-Pine Bluff
# Ball St. NIU
# Houston Baptist A&M-Corpus Christi
# Akron Kent St.
# Central Ark. Eastern Ky.
# Eastern Mich. Toledo
# Maine Hartford
# Liberty Stetson
# Bellarmine Jacksonville St.
# Charleston So. Gardner-Webb
# UCF Tulane
# South Fla. Cincinnati
# Houston Wichita St.
# UNC Asheville Longwood
# Boston U. Loyola Maryland
# Iowa St. Oklahoma
# Western Mich. Central Mich.
# Buffalo Bowling Green
# Kansas St. Oklahoma St.
# Indiana Wisconsin
# Texas Tech Texas
# Tulsa Memphis
# Saint Louis Fordham

# %%
import nba_stats_tracking as nba
# Out:
# {'__name__': 'builtins',
#  '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.",
#  '__package__': '',
#  '__loader__': _frozen_importlib.BuiltinImporter,
#  '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in'),
#  '__build_class__': <function __build_class__>,
#  '__import__': <function __import__>,
#  'abs': <function abs(x, /)>,
#  'all': <function all(iterable, /)>,
#  'any': <function any(iterable, /)>,
#  'ascii': <function ascii(obj, /)>,
#  'bin': <function bin(number, /)>,
#  'breakpoint': <function breakpoint>,
#  'callable': <function callable(obj, /)>,
#  'chr': <function chr(i, /)>,
#  'compile': <function compile(source, filename, mode, flags=0, dont_inherit=False, optimize=-1, *, _feature_version=-1)>,
#  'delattr': <function delattr(obj, name, /)>,
#  'dir': <function dir>,
#  'divmod': <function divmod(x, y, /)>,
# ...
